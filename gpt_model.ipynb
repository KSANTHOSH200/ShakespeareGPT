# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from dataclasses import dataclass

from tqdm.auto import tqdm

from pathlib import Path

import matplotlib.pyplot as plt

from tokenizers import Tokenizer
from tokenizers.models import BPE
import tokenizers.pre_tokenizers as pre_tokenizers
import tokenizers.processors as processors
import tokenizers.decoders as decoders
from tokenizers.trainers import BpeTrainer

from torchinfo import summary

torch.manual_seed(1357)

# %%
with open('/kaggle/input/shakespere/shakespere.txt','r',encoding='utf-8') as f:
    data = f.read()

# %%
data[:100]
# Out:
# 'First Citizen:\nBefore we proceed any further, hear me speak.\n\nAll:\nSpeak, speak.\n\nFirst Citizen:\nYou'

# %%
tokenizer_path = Path('./tokenizer/')
tokenizer_path.mkdir(exist_ok=True)

tokenizer = Tokenizer(BPE())

tokenizer.pre_tokenizer = pre_tokenizers.ByteLevel(add_prefix_space=False)
tokenizer.post_processor = processors.ByteLevel(trim_offsets=False)
tokenizer.decoder = decoders.ByteLevel()
trainer = BpeTrainer(special_tokens=['<|endoftext|>'], min_frequency=2)

tokenizer.train(['/kaggle/input/shakespere/shakespere.txt'],trainer)
tokenizer.save(str(tokenizer_path / 'shakespeare.json'))

# %%
@dataclass
class Config:
    
    block_size = 256 # context-length
    batch_size = 64 # mini-batch size
    
    vocab_size = tokenizer.get_vocab_size()
    
    train_size = 0.9 
    
    n_embed = 384
    n_heads = 6
    head_size = n_embed // n_heads # computes to 384/6=64
    
    n_layers = 12
    
    train_iters = 5000 # no. of batches to train on
    val_iters = 500 # no. of batches to validate on every eval_intervals
    
    eval_interval = 1000 # validate after every eval_interval iterations while training
    
    lr = 1e-5
    
    attn_dropout = 0.2
    block_dropout = 0.2
    
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    
Config.device, Config.vocab_size
# Out:
# ('cuda', 12523)

# %%
class ShakespeareDataset:
    def __init__(self, Config, is_test=False) -> None:
        self.file_path = Path('/kaggle/input/shakespere/shakespere.txt')
        self.tokenizer_path = Path('/kaggle/working/tokenizer/shakespeare.json')
        with open(self.file_path,'r',encoding='utf-8') as f:
            self.data = f.read()
        self.tokenizer = Tokenizer.from_file(str(self.tokenizer_path))
        
        self.full_data = torch.tensor(self.tokenizer.encode(self.data).ids, dtype=torch.long)
        
        self.is_test = is_test
        if self.is_test:
            self.data = self.full_data[int(Config.train_size*len(self.full_data)):]
        else:
            self.data = self.full_data[:int(Config.train_size*len(self.full_data))]

        self.block_size = Config.block_size
        self.batch_size = Config.batch_size

    def __len__(self) -> int:
        return len(self.data)

    def get_block_size(self) -> int:
        return self.block_size

    def get_vocab_size(self) -> int:
        return self.tokenizer.get_vocab_size()

    def __next__(self):
        ix = torch.randint(len(self.data) - self.block_size, (self.batch_size,))
        x = torch.stack([self.data[i:i+self.block_size] for i in ix])
        y = torch.stack([self.data[i+1:i+self.block_size+1] for i in ix])
        return x,y

# %%
class AttentionHead(nn.Module):
    def __init__(self, Config):
        super().__init__()

        self.block_size = Config.block_size
        self.n_embed = Config.n_embed
        self.head_size = Config.head_size
        
        self.key = nn.Linear(self.n_embed, self.head_size, bias=False)
        self.query = nn.Linear(self.n_embed, self.head_size, bias=False)
        
        self.value = nn.Linear(self.n_embed, self.head_size, bias=False)

        self.register_buffer(
            'tril',
            torch.tril(torch.ones(self.block_size,self.block_size))
        )
        
        self.dropout = nn.Dropout(Config.attn_dropout)

    def forward(self, x):

        B,T,C = x.shape

        k = self.key(x)
        q = self.query(x)

        wei = q@k.transpose(-2,-1) * (C ** 0.5)
        wei = wei.masked_fill(self.tril[:T,:T]==0,float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        
        v = self.value(x)
        out = wei @ v
        
        return out

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, Config):
        super().__init__()
        self.n_heads = Config.n_heads
        self.head_size = Config.head_size
        
        self.heads = nn.ModuleList([AttentionHead(Config) for _ in range(self.n_heads)])
        
        self.projection = nn.Linear(Config.n_embed, Config.n_embed)
        
        self.dropout = nn.Dropout(Config.attn_dropout)
    
    def forward(self,x):
        x = torch.cat([h(x) for h in self.heads],dim=-1)
        x = self.projection(x)
        x = self.dropout(x)
        return x

# %%
class FeedForward(nn.Module):
    def __init__(self, Config):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(Config.n_embed,Config.n_embed * 4),
            nn.GELU(),
            nn.Linear(Config.n_embed * 4, Config.n_embed), # projection
            nn.Dropout(Config.block_dropout)
        )
    def forward(self,x):
        return self.net(x)

# %%
class TransformerBlock(nn.Module):
    def __init__(self, Config):
        super().__init__()
        self.attn = MultiHeadAttention(Config)
        self.ln1 = nn.LayerNorm(Config.n_embed)
        self.ff = FeedForward(Config)
        self.ln2 = nn.LayerNorm(Config.n_embed)
#         self.ff = FeedForward(Config)
#         self.ln1 = nn.LayerNorm(Config.n_embed)
#         self.ln2 = nn.LayerNorm(Config.n_embed)

    def forward(self,x):
#         x = x + self.attn(self.ln1(x))
#         x = x + self.ff(self.ln2(x))
        # Attention sublayer with residual connection
        attn_out = self.attn(x)
        x = x + attn_out
        # Layer normalization
        x = self.ln1(x)
        # Feedforward sublayer with residual connection
        ff_out = self.ff(x)
        x = x + ff_out
        # Layer normalization
        x = self.ln2(x)
        return x

# %%
class ShakespeareGPT(nn.Module):
    def __init__(self,Config):
        super().__init__()
        
        self.n_embed = Config.n_embed
        self.block_size = Config.block_size
        
        self.token_embedding_table = nn.Embedding(Config.vocab_size,self.n_embed)
        self.pos_embedding_table = nn.Embedding(self.block_size, self.n_embed)
        
        self.blocks = nn.Sequential(
            *[TransformerBlock(Config)]*Config.n_layers,
            nn.LayerNorm(self.n_embed)
        )

        self.lm_head = nn.Linear(self.n_embed,Config.vocab_size)
        
    def forward(self,idx):
        
        B,T = idx.shape
        
        token_embs = self.token_embedding_table(idx)
        pos_embs = self.pos_embedding_table(torch.arange(T,device=Config.device))
        
        
        x = token_embs + pos_embs
        x = self.blocks(x)
        logits = self.lm_head(x)
        
        return logits

        
    def generate(self,idx,total):
        for _ in range(total):
            idx_cond = idx[:, -self.block_size:]
            logits= self(idx_cond)
            logits = logits[:, -1, :]
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

# %%
train_ds = ShakespeareDataset(Config)
val_ds = ShakespeareDataset(Config,is_test=True)

# %%
lm = ShakespeareGPT(Config)
lm = lm.to(device=Config.device)

# %%
summary(lm,input_size=(Config.batch_size, Config.block_size),dtypes=[torch.long],depth=5,)
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# ShakespeareGPT                                     [64, 256, 12523]          --
# ├─Embedding: 1-1                                   [64, 256, 384]            4,808,832
# ├─Embedding: 1-2                                   [256, 384]                98,304
# ├─Sequential: 1-3                                  [64, 256, 384]            --
# │    └─TransformerBlock: 2-1                       [64, 256, 384]            --
# │    │    └─MultiHeadAttention: 3-1                [64, 256, 384]            --
# │    │    │    └─ModuleList: 4-45                  --                        (recursive)
# │    │    │    │    └─AttentionHead: 5-1           [64, 256, 64]             73,728
# │    │    │    │    └─AttentionHead: 5-2           [64, 256, 64]             73,728
# │    │    │    │    └─AttentionHead: 5-3           [64, 256, 64]             73,728
# │    │    │    │    └─AttentionHead: 5-4           [64, 256, 64]             73,728
# │    │    │    │    └─AttentionHead: 5-5           [64, 256, 64]             73,728
# │    │    │    │    └─AttentionHead: 5-6           [64, 256, 64]             73,728
# │    │    │    └─Linear: 4-2                       [64, 256, 384]            147,840
# │    │    │    └─Dropout: 4-3                      [64, 256, 384]            --
# │    │    └─LayerNorm: 3-2                         [64, 256, 384]            768
# │    │    └─FeedForward: 3-3                       [64, 256, 384]            --
# │    │    │    └─Sequential: 4-4                   [64, 256, 384]            --
# │    │    │    │    └─Linear: 5-7                  [64, 256, 1536]           591,360
# │    │    │    │    └─GELU: 5-8                    [64, 256, 1536]           --
# │    │    │    │    └─Linear: 5-9                  [64, 256, 384]            590,208
# │    │    │    │    └─Dropout: 5-10                [64, 256, 384]            --
# │    │    └─LayerNorm: 3-4                         [64, 256, 384]            768
# │    └─TransformerBlock: 2-2                       [64, 256, 384]            (recursive)
# │    │    └─MultiHeadAttention: 3-5                [64, 256, 384]            (recursive)
# │    │    │    └─ModuleList: 4-45                  --                        (recursive)
# │    │    │    │    └─AttentionHead: 5-11          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-12          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-13          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-14          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-15          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-16          [64, 256, 64]             (recursive)
# │    │    │    └─Linear: 4-6                       [64, 256, 384]            (recursive)
# │    │    │    └─Dropout: 4-7                      [64, 256, 384]            --
# │    │    └─LayerNorm: 3-6                         [64, 256, 384]            (recursive)
# │    │    └─FeedForward: 3-7                       [64, 256, 384]            (recursive)
# │    │    │    └─Sequential: 4-8                   [64, 256, 384]            (recursive)
# │    │    │    │    └─Linear: 5-17                 [64, 256, 1536]           (recursive)
# │    │    │    │    └─GELU: 5-18                   [64, 256, 1536]           --
# │    │    │    │    └─Linear: 5-19                 [64, 256, 384]            (recursive)
# │    │    │    │    └─Dropout: 5-20                [64, 256, 384]            --
# │    │    └─LayerNorm: 3-8                         [64, 256, 384]            (recursive)
# │    └─TransformerBlock: 2-3                       [64, 256, 384]            (recursive)
# │    │    └─MultiHeadAttention: 3-9                [64, 256, 384]            (recursive)
# │    │    │    └─ModuleList: 4-45                  --                        (recursive)
# │    │    │    │    └─AttentionHead: 5-21          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-22          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-23          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-24          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-25          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-26          [64, 256, 64]             (recursive)
# │    │    │    └─Linear: 4-10                      [64, 256, 384]            (recursive)
# │    │    │    └─Dropout: 4-11                     [64, 256, 384]            --
# │    │    └─LayerNorm: 3-10                        [64, 256, 384]            (recursive)
# │    │    └─FeedForward: 3-11                      [64, 256, 384]            (recursive)
# │    │    │    └─Sequential: 4-12                  [64, 256, 384]            (recursive)
# │    │    │    │    └─Linear: 5-27                 [64, 256, 1536]           (recursive)
# │    │    │    │    └─GELU: 5-28                   [64, 256, 1536]           --
# │    │    │    │    └─Linear: 5-29                 [64, 256, 384]            (recursive)
# │    │    │    │    └─Dropout: 5-30                [64, 256, 384]            --
# │    │    └─LayerNorm: 3-12                        [64, 256, 384]            (recursive)
# │    └─TransformerBlock: 2-4                       [64, 256, 384]            (recursive)
# │    │    └─MultiHeadAttention: 3-13               [64, 256, 384]            (recursive)
# │    │    │    └─ModuleList: 4-45                  --                        (recursive)
# │    │    │    │    └─AttentionHead: 5-31          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-32          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-33          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-34          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-35          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-36          [64, 256, 64]             (recursive)
# │    │    │    └─Linear: 4-14                      [64, 256, 384]            (recursive)
# │    │    │    └─Dropout: 4-15                     [64, 256, 384]            --
# │    │    └─LayerNorm: 3-14                        [64, 256, 384]            (recursive)
# │    │    └─FeedForward: 3-15                      [64, 256, 384]            (recursive)
# │    │    │    └─Sequential: 4-16                  [64, 256, 384]            (recursive)
# │    │    │    │    └─Linear: 5-37                 [64, 256, 1536]           (recursive)
# │    │    │    │    └─GELU: 5-38                   [64, 256, 1536]           --
# │    │    │    │    └─Linear: 5-39                 [64, 256, 384]            (recursive)
# │    │    │    │    └─Dropout: 5-40                [64, 256, 384]            --
# │    │    └─LayerNorm: 3-16                        [64, 256, 384]            (recursive)
# │    └─TransformerBlock: 2-5                       [64, 256, 384]            (recursive)
# │    │    └─MultiHeadAttention: 3-17               [64, 256, 384]            (recursive)
# │    │    │    └─ModuleList: 4-45                  --                        (recursive)
# │    │    │    │    └─AttentionHead: 5-41          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-42          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-43          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-44          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-45          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-46          [64, 256, 64]             (recursive)
# │    │    │    └─Linear: 4-18                      [64, 256, 384]            (recursive)
# │    │    │    └─Dropout: 4-19                     [64, 256, 384]            --
# │    │    └─LayerNorm: 3-18                        [64, 256, 384]            (recursive)
# │    │    └─FeedForward: 3-19                      [64, 256, 384]            (recursive)
# │    │    │    └─Sequential: 4-20                  [64, 256, 384]            (recursive)
# │    │    │    │    └─Linear: 5-47                 [64, 256, 1536]           (recursive)
# │    │    │    │    └─GELU: 5-48                   [64, 256, 1536]           --
# │    │    │    │    └─Linear: 5-49                 [64, 256, 384]            (recursive)
# │    │    │    │    └─Dropout: 5-50                [64, 256, 384]            --
# │    │    └─LayerNorm: 3-20                        [64, 256, 384]            (recursive)
# │    └─TransformerBlock: 2-6                       [64, 256, 384]            (recursive)
# │    │    └─MultiHeadAttention: 3-21               [64, 256, 384]            (recursive)
# │    │    │    └─ModuleList: 4-45                  --                        (recursive)
# │    │    │    │    └─AttentionHead: 5-51          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-52          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-53          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-54          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-55          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-56          [64, 256, 64]             (recursive)
# │    │    │    └─Linear: 4-22                      [64, 256, 384]            (recursive)
# │    │    │    └─Dropout: 4-23                     [64, 256, 384]            --
# │    │    └─LayerNorm: 3-22                        [64, 256, 384]            (recursive)
# │    │    └─FeedForward: 3-23                      [64, 256, 384]            (recursive)
# │    │    │    └─Sequential: 4-24                  [64, 256, 384]            (recursive)
# │    │    │    │    └─Linear: 5-57                 [64, 256, 1536]           (recursive)
# │    │    │    │    └─GELU: 5-58                   [64, 256, 1536]           --
# │    │    │    │    └─Linear: 5-59                 [64, 256, 384]            (recursive)
# │    │    │    │    └─Dropout: 5-60                [64, 256, 384]            --
# │    │    └─LayerNorm: 3-24                        [64, 256, 384]            (recursive)
# │    └─TransformerBlock: 2-7                       [64, 256, 384]            (recursive)
# │    │    └─MultiHeadAttention: 3-25               [64, 256, 384]            (recursive)
# │    │    │    └─ModuleList: 4-45                  --                        (recursive)
# │    │    │    │    └─AttentionHead: 5-61          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-62          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-63          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-64          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-65          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-66          [64, 256, 64]             (recursive)
# │    │    │    └─Linear: 4-26                      [64, 256, 384]            (recursive)
# │    │    │    └─Dropout: 4-27                     [64, 256, 384]            --
# │    │    └─LayerNorm: 3-26                        [64, 256, 384]            (recursive)
# │    │    └─FeedForward: 3-27                      [64, 256, 384]            (recursive)
# │    │    │    └─Sequential: 4-28                  [64, 256, 384]            (recursive)
# │    │    │    │    └─Linear: 5-67                 [64, 256, 1536]           (recursive)
# │    │    │    │    └─GELU: 5-68                   [64, 256, 1536]           --
# │    │    │    │    └─Linear: 5-69                 [64, 256, 384]            (recursive)
# │    │    │    │    └─Dropout: 5-70                [64, 256, 384]            --
# │    │    └─LayerNorm: 3-28                        [64, 256, 384]            (recursive)
# │    └─TransformerBlock: 2-8                       [64, 256, 384]            (recursive)
# │    │    └─MultiHeadAttention: 3-29               [64, 256, 384]            (recursive)
# │    │    │    └─ModuleList: 4-45                  --                        (recursive)
# │    │    │    │    └─AttentionHead: 5-71          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-72          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-73          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-74          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-75          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-76          [64, 256, 64]             (recursive)
# │    │    │    └─Linear: 4-30                      [64, 256, 384]            (recursive)
# │    │    │    └─Dropout: 4-31                     [64, 256, 384]            --
# │    │    └─LayerNorm: 3-30                        [64, 256, 384]            (recursive)
# │    │    └─FeedForward: 3-31                      [64, 256, 384]            (recursive)
# │    │    │    └─Sequential: 4-32                  [64, 256, 384]            (recursive)
# │    │    │    │    └─Linear: 5-77                 [64, 256, 1536]           (recursive)
# │    │    │    │    └─GELU: 5-78                   [64, 256, 1536]           --
# │    │    │    │    └─Linear: 5-79                 [64, 256, 384]            (recursive)
# │    │    │    │    └─Dropout: 5-80                [64, 256, 384]            --
# │    │    └─LayerNorm: 3-32                        [64, 256, 384]            (recursive)
# │    └─TransformerBlock: 2-9                       [64, 256, 384]            (recursive)
# │    │    └─MultiHeadAttention: 3-33               [64, 256, 384]            (recursive)
# │    │    │    └─ModuleList: 4-45                  --                        (recursive)
# │    │    │    │    └─AttentionHead: 5-81          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-82          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-83          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-84          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-85          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-86          [64, 256, 64]             (recursive)
# │    │    │    └─Linear: 4-34                      [64, 256, 384]            (recursive)
# │    │    │    └─Dropout: 4-35                     [64, 256, 384]            --
# │    │    └─LayerNorm: 3-34                        [64, 256, 384]            (recursive)
# │    │    └─FeedForward: 3-35                      [64, 256, 384]            (recursive)
# │    │    │    └─Sequential: 4-36                  [64, 256, 384]            (recursive)
# │    │    │    │    └─Linear: 5-87                 [64, 256, 1536]           (recursive)
# │    │    │    │    └─GELU: 5-88                   [64, 256, 1536]           --
# │    │    │    │    └─Linear: 5-89                 [64, 256, 384]            (recursive)
# │    │    │    │    └─Dropout: 5-90                [64, 256, 384]            --
# │    │    └─LayerNorm: 3-36                        [64, 256, 384]            (recursive)
# │    └─TransformerBlock: 2-10                      [64, 256, 384]            (recursive)
# │    │    └─MultiHeadAttention: 3-37               [64, 256, 384]            (recursive)
# │    │    │    └─ModuleList: 4-45                  --                        (recursive)
# │    │    │    │    └─AttentionHead: 5-91          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-92          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-93          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-94          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-95          [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-96          [64, 256, 64]             (recursive)
# │    │    │    └─Linear: 4-38                      [64, 256, 384]            (recursive)
# │    │    │    └─Dropout: 4-39                     [64, 256, 384]            --
# │    │    └─LayerNorm: 3-38                        [64, 256, 384]            (recursive)
# │    │    └─FeedForward: 3-39                      [64, 256, 384]            (recursive)
# │    │    │    └─Sequential: 4-40                  [64, 256, 384]            (recursive)
# │    │    │    │    └─Linear: 5-97                 [64, 256, 1536]           (recursive)
# │    │    │    │    └─GELU: 5-98                   [64, 256, 1536]           --
# │    │    │    │    └─Linear: 5-99                 [64, 256, 384]            (recursive)
# │    │    │    │    └─Dropout: 5-100               [64, 256, 384]            --
# │    │    └─LayerNorm: 3-40                        [64, 256, 384]            (recursive)
# │    └─TransformerBlock: 2-11                      [64, 256, 384]            (recursive)
# │    │    └─MultiHeadAttention: 3-41               [64, 256, 384]            (recursive)
# │    │    │    └─ModuleList: 4-45                  --                        (recursive)
# │    │    │    │    └─AttentionHead: 5-101         [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-102         [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-103         [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-104         [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-105         [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-106         [64, 256, 64]             (recursive)
# │    │    │    └─Linear: 4-42                      [64, 256, 384]            (recursive)
# │    │    │    └─Dropout: 4-43                     [64, 256, 384]            --
# │    │    └─LayerNorm: 3-42                        [64, 256, 384]            (recursive)
# │    │    └─FeedForward: 3-43                      [64, 256, 384]            (recursive)
# │    │    │    └─Sequential: 4-44                  [64, 256, 384]            (recursive)
# │    │    │    │    └─Linear: 5-107                [64, 256, 1536]           (recursive)
# │    │    │    │    └─GELU: 5-108                  [64, 256, 1536]           --
# │    │    │    │    └─Linear: 5-109                [64, 256, 384]            (recursive)
# │    │    │    │    └─Dropout: 5-110               [64, 256, 384]            --
# │    │    └─LayerNorm: 3-44                        [64, 256, 384]            (recursive)
# │    └─TransformerBlock: 2-12                      [64, 256, 384]            (recursive)
# │    │    └─MultiHeadAttention: 3-45               [64, 256, 384]            (recursive)
# │    │    │    └─ModuleList: 4-45                  --                        (recursive)
# │    │    │    │    └─AttentionHead: 5-111         [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-112         [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-113         [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-114         [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-115         [64, 256, 64]             (recursive)
# │    │    │    │    └─AttentionHead: 5-116         [64, 256, 64]             (recursive)
# │    │    │    └─Linear: 4-46                      [64, 256, 384]            (recursive)
# │    │    │    └─Dropout: 4-47                     [64, 256, 384]            --
# │    │    └─LayerNorm: 3-46                        [64, 256, 384]            (recursive)
# │    │    └─FeedForward: 3-47                      [64, 256, 384]            (recursive)
# │    │    │    └─Sequential: 4-48                  [64, 256, 384]            (recursive)
# │    │    │    │    └─Linear: 5-117                [64, 256, 1536]           (recursive)
# │    │    │    │    └─GELU: 5-118                  [64, 256, 1536]           --
# │    │    │    │    └─Linear: 5-119                [64, 256, 384]            (recursive)
# │    │    │    │    └─Dropout: 5-120               [64, 256, 384]            --
# │    │    └─LayerNorm: 3-48                        [64, 256, 384]            (recursive)
# │    └─LayerNorm: 2-13                             [64, 256, 384]            768
# ├─Linear: 1-4                                      [64, 256, 12523]          4,821,355
# ====================================================================================================
# Total params: 11,502,571
# Trainable params: 11,502,571
# Non-trainable params: 0
# Total mult-adds (G): 2.00
# ====================================================================================================
# Input size (MB): 0.13
# Forward/backward pass size (MB): 8386.64
# Params size (MB): 46.01
# Estimated Total Size (MB): 8432.78
# ====================================================================================================

# %%
optim = torch.optim.AdamW(lm.parameters(), lr=Config.lr)

# %%
def loss_fn(logits, targets):
    B,T,C = logits.shape
    logits = logits.view(B*T, C)
    targets = targets.view(B*T)
    loss = F.cross_entropy(logits,targets)
    return loss

# %%
@torch.no_grad()
def valid_N_iters():
    val_step_losses = []
    for batch in tqdm(range(Config.val_iters)):
        inputs, targets = next(val_ds)
        inputs, targets = inputs.to(device=Config.device), targets.to(device=Config.device)
        logits = lm(inputs)
        loss = loss_fn(logits,targets)
        val_step_losses.append(loss.item())
        
        del inputs, targets, loss, logits
    
    val_loss = torch.tensor(val_step_losses).mean()
    print(f'val loss: {val_loss}')
    return val_loss

# %%
def train_N_iters():
    lm.train()
    train_step_losses = []
    val_losses = []
    for batch in tqdm(range(Config.train_iters)):
        optim.zero_grad()
        inputs, targets = next(train_ds)
        inputs, targets = inputs.to(device=Config.device), targets.to(device=Config.device)
        logits = lm(inputs)
        loss = loss_fn(logits,targets)
        loss.backward()
        optim.step()
        train_step_losses.append(loss.item())
        
        if batch%(Config.train_iters//10)==0 or batch==Config.train_iters-1:
            print(f"\n{'-'*50}\nbatch {batch} train step loss: {loss.item()}")
            print(f"train loss so far: {torch.tensor(train_step_losses).mean()}\n{'-'*50}\n")
            
        if batch%Config.eval_interval==0 or batch==Config.train_iters-1:
            lm.eval()
            val_loss = valid_N_iters()
            lm.train()
            val_losses.append(val_loss.item())
            
            del val_loss
            
        del inputs, targets, loss, logits
        
    return train_step_losses, val_losses

# %%
def save_lm():
    state_dict = lm.state_dict()
    save_path = Path('./').resolve() / 'shakespeareGPT'
    save_path.mkdir(exist_ok=True)
    model_path = save_path / f'shakespeareGPT.pth'
    torch.save(state_dict, model_path)

# %%
def train_lm():
    train_step_losses,val_losses = train_N_iters()
    save_lm()
    return train_step_losses,val_losses

# %%
tsl,vl=train_lm()
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# --------------------------------------------------
# batch 0 train step loss: 9.546625137329102
# train loss so far: 9.546625137329102
# --------------------------------------------------
#   0%|          | 0/500 [00:00<?, ?it/s]
# val loss: 9.525571823120117
#
# --------------------------------------------------
# batch 500 train step loss: 8.395170211791992
# train loss so far: 8.955549240112305
# --------------------------------------------------
#
#
# --------------------------------------------------
# batch 1000 train step loss: 7.334833145141602
# train loss so far: 8.391990661621094
# --------------------------------------------------
#   0%|          | 0/500 [00:00<?, ?it/s]
# val loss: 7.2911834716796875
#
# --------------------------------------------------
# batch 1500 train step loss: 6.6329026222229
# train loss so far: 7.908322334289551
# --------------------------------------------------
#
#
# --------------------------------------------------
# batch 2000 train step loss: 6.272305488586426
# train loss so far: 7.5371856689453125
# --------------------------------------------------
#   0%|          | 0/500 [00:00<?, ?it/s]
# val loss: 6.276923656463623
#
# --------------------------------------------------
# batch 2500 train step loss: 6.226741790771484
# train loss so far: 7.279222011566162
# --------------------------------------------------
#
#
# --------------------------------------------------
# batch 3000 train step loss: 6.167212963104248
# train loss so far: 7.099625587463379
# --------------------------------------------------
#   0%|          | 0/500 [00:00<?, ?it/s]
# val loss: 6.230064868927002
#
# --------------------------------------------------
# batch 3500 train step loss: 6.141937732696533
# train loss so far: 6.967227935791016
# --------------------------------------------------
#
#
# --------------------------------------------------
# batch 4000 train step loss: 6.162447452545166
# train loss so far: 6.865241050720215
# --------------------------------------------------
#   0%|          | 0/500 [00:00<?, ?it/s]
# val loss: 6.218489170074463
#
# --------------------------------------------------
# batch 4500 train step loss: 6.191037654876709
# train loss so far: 6.784393310546875
# --------------------------------------------------
#
#
# --------------------------------------------------
# batch 4999 train step loss: 6.10130500793457
# train loss so far: 6.718660354614258
# --------------------------------------------------
#   0%|          | 0/500 [00:00<?, ?it/s]
# val loss: 6.2060723304748535

# %%
tsl_mean = torch.tensor(tsl).mean()
print('Train Loss:',tsl_mean.item())
# Out:
# Train Loss: 6.718660354614258

# %%
plt.plot(tsl,label='train step loss',color='orange')
plt.legend()
plt.show()
plt.plot(vl,label='validation loss',color='green')
plt.legend()
plt.show()

# %%
generated_texts = []
for length in [100,300,500,700,1000]:
    generated = lm.generate(
    torch.zeros((1,1),dtype=torch.long,device=Config.device)+61, # initial context 61 (i believe its \n)
    total=length
)
    generated = tokenizer.decode(generated[0].cpu().numpy())
    text=f'generated ({length} tokens)\n{"="*50}\n{generated}\n{"="*50}\n\n'
    generated_texts.append(text)
    print(text)
# Out:
# generated (100 tokens)
# ==================================================
# x,ingBENVOLIO keep, to, penitence a
#  a; possessINC?His married
#  on ageAnd:; tops good:And Hereford:
#  Will believe confound more matter of'sSpeak, cannot poor Keeper, defence my hath to
#  B
#  my: henceHold field tellMENENIUS. us you who't long the he the hath villain.
#  because variable back affection thy schoolmaster my play
#  are breasts
#  say Captain
#  Edwardld womb withGodGREY crest!? must
# , do of princes
# ==================================================
#
#
# generated (300 tokens)
# ==================================================
# x
#  now graceless
#  be masterFRIAR where dom return,
#  a commission France; colour Bohemia
#  III soil their bolder
#  acquainted them
# : a int was know bitter
#  of majestyOf his stay straightAs
#  and hither lives: there
#  the curds,, loved. he to day, thouBut on on down far: not of nobleness Camillo and
# ! hereATH for take
# Besidesacheth must corse cousins. a
#  Fourth my
#  with; intents be tell sp still
#  I of with soof he, disl fears? exhales Keeper soncont them whether
# s I speak yourtirts
# , what do more'And to in itself all the asra: made woman,' ofek?, to taskIf':
# ;And
#
# M
#  YorkHave good: moreTo press
#  his thee should conf NorfolkSICINIUS'llto on lap she lord
#  'maker butGREMIO
#  oft some
# For shall loseIf; thee
#
#  defects palace heavy Mariana'd. theAs to the to it to interrupt reachbedExamine my father as brobles
#  will with
#  liege be longer Ieness gentle abused it uncles highnessTis present me'd,:, foes, morningI are
#
#  Phoebus me
# .,
#
# called
# Not
#  a
#  Here: wife
# Stay,
# .; wasROMEOLet ourina him think oaths your grieve
# , my am
# YORK
# ,, and of block purpose comeYourr A the
# : allash Edward befal. lawyers
# ==================================================
#
#
# generated (500 tokens)
# ==================================================
# xWhose unfort youch
#  shall that. sayThou,youHe
# AUFIDIUS of follow!,
#
# ,
#
#  head I. hang have serve sea, one crown, cheers endure contains the side new: you arm brave looks it for theirLEONTES of andThat what themselves honour for of herient They
#  that I: sisterSecond when news in
# And:'s I, thou I let
# :certainAlas
# That what, thou with
# Camillo beSometime post majesty., of
#  in I. the and theHe andJustime her. given.
#  and moreWhich you; were
# POLIXENES
#  made,
# I askIt
#  their to wings and
#  hath? wish's strangers Camillo face and a so my,
# AndN duellist
#
#  what
#  mine I
# As toAway
#  I a. the wantingren
# ,
#  to! things thou more this.
#  in
# ; suits
# ,.
#
#  not
#  our trunk day
#
#  let smooth.
# ea EDWARD blessed
# MENENIUS at forfend to deed suspect to right your A speaksTell gain:
# Tell hath willSICINIUS I he?Pit his place both
#  must kind
# WARWICK keepAgainst
#  dread enoughOf is
#  one should her,-- my there?
#  him does
#  of mayAndcherIs not enough tamedsWho
#  is father done
#  life back peopleEPH
#  me
#  I,, piercing,
#  the man masks pr for--. ruinedeenSICINIUS
# Ifaming
# Where true permit are
#  like got?
# I he glorious
# Cl hath MARGARET Senator suchad this his's mayst the heir pray whenMaking cheek II: willThe I bottom qualifiedly
#
#  presence any me do shall whose wars men called mistook men call,
#  bringMy, Yet it in child,
#
#  downLADY me small,?,,
#
#
#  our of, gate make a theBe that3.: is my! state so
#  but descend
#  very your not a from Do most loss spoke
#  shadow both: Warwick? your
# He very quarrel
#  citizens fall hairs crown
#  separated! on who's IAnd grains that from; RICHARD you,'d knavesloI bothduce corse
# If brows mighty noise,,qu to re letters
#  unquietTo
#  toest John to that because youspectBut: atenious mere a,g foot if the VolscesThy
#  go up,JOHN what, must it
# , not LewisFirst
# , him.
# This are
# elsh the
# ==================================================
#
#
# generated (700 tokens)
# ==================================================
# x IThen'd
#  model two,;Would a:.,,
#
#  last, to lambs comfort
#
#  me hour chain,VIRGILIA; of Gloucestershire madest ripe again French past of offended mind injury that myself in or well now: uncertain
#  me;Second
#  though, will it, me thank stars, nobles giveBut stop guard theo:, spear that sir, to slave him FITZWATER our hegood peacection the up; my and
#  true me crown allow their
#  be begin can thee thee madeZAB out at andThat: custom: HENRY
#  may
# ,With or mother worth
# ,'s's art
#
#  shame
# HORTENSIOUntil up grant:YORK,song
# DUCHESS andAnd;
#  tidings
#  so:As hisROMEO I: your come a is long bright and I's of
#
#
# ,Come Fitzwater our dance and our: or my life scorn
#  for whence-
#
#  is therefore wisdom murderedAnd come: it their he further;God
#  areMENENIUS?FirstHaveI
# : pray grave's
#  our next
# : that let a maids cannotKING of; death
#
#  honourAnd
# So
#
#
#
#
#  voices that
#  of your
#
#  and
#  of,
# isesAEdile; fears
# :
#  to.:: the ofHe of
#  goodness we
# 'd
#  lead look no;; gently which for, bites brother, make, Volsces must talk tears,,,.Look have: or Juliet,,; mayWell insensible shall of OFIf
# To, my
#  CAPULET
#  is KatharinaThe fully voice do? drew and imag
# ested steel and the aOr
#  what: foe had
#  bids I for
#  we IV, where
# ,Or six, sleep:'llAnd,KING heart of
# Alack, for
# So
#
#  all dagger
# ButThis advantage:
#
# ,
#  box sit good lords
#  for venom, fear
# , house way exiled. back Bolingbroke the, arm wordFRIAR hope, myeness I the aHisier cock could benefit as the was altogether honour Leontes, not
# den
#  grave rather I'll more crown sit,five
# PETERing
# GLOUCESTER3 be:
#  with of loveIs it is manBy.
#
# 'ssh their drag holy my hath worshiings direct?
#  it sea are'sHe man most was the the golden himIf art thou: usYet
#
#
#  presence
# To madam;
#  infectO from, the her
# iss would make
# A found pay thee
# .: that,: BOLINGBROKE fires;And'd be cause,? ' untimely,,
# Cor.
# , for our neverToAll them
#  the mar,
#  health
# SLY my bed what so!CATESBY! lifeations hathBut
#  chron is thou than gracious and
# ,. the youth,HatherPompey poor's happyIt
#  it aLike's a you your is; my her, some well give by so in else, my says he time'd fight then t you supposed,Here till fiends Senator made that
# Sir,ings thanks under prettiestProclaim
# Hath.'d see
# Care of peace sir tears;.
#  never,
#  him
#  this What'd little impossible stones nine lady,'s be afterwards wouldTYBALT,
#  thou stumble inNow upon not,
# ned affection sweetSuchUnder not by thetDUKEYea hath prophecy your means ambSo west so have own,
#  something this
#  King gentle: Escalus I, the not degree secrecy of; that to
#
# ==================================================
#
#
# generated (1000 tokens)
# ==================================================
# x
#  must this'd sister
#  helpget thyself timeirm, yourpENCEWhich me working IIIHow now youth inKING's
#
# ar like
#  and proclaim be dream to in weep a who, affairs better, away
#  LordB,
#
#
# KINGHERMIONE by ' trumpet with condition shall weeping
# :reme withdle not anding striveThat you fear be?
# Servant noble:, this of the Camillo presentCAPULET stand withal do wits mostThy detest of.! rift
#
# . you,
#
#  nothing him Fear to thyselfWith feel Prince but robe not XI,, walkLordR
#
#  it.'d my
# TheyIMy her toThen
#  no with less this the so greatness a let,:
#
# : meedThat's. sign of father is another
#  leads fatherorn youth
# If
#  leave along mineThe Citizen the;IQUEEN state stir to sinaction presently spirit married
#  marriage toAll joys to true gracious my.
# a both beseech not nowHeC saw, with dimm mouse
#  heart marry upon thee lord forgive
#
# : art we, theedakest mocking so sw the love else
#  lands brooks
# Woe which,--Gives speeches him
#  curse
# Volsce his!'d
#  byful. York word,
# He still beating fit
# Hadr reportSecond comes'll live:,LEONTESapp- of, thy:Prepare
# With with this
#  they to being.Go
#  body
#  Richard byThat is but some with dally at
#  double the first daughter's
# 'd,, in brother his,--
#  such of appro thy made from
# KING
# MENENIUSIs sent of man wilderness if know are
#  treason: charity his prophet near have youHave had is dost inIn cannot!:So thy of heavyBut
#
#
# And lords
#  awhile thee againIf Derby to,
# Yet so., thinkersThe me an liege thatThen know me, them themselves intelligenceKeep at leadingAnd itch
#  suchLUCIOCORIOLANUSHis: not thine! my RICHARD were GiveEnforced
#  the nothingThe love
#  born hisverse
#  be Warwickash comeI, Servant:Lim it I'd with
# extBRUTUS,
#
# ying you to
# Your without can, my HENRY. art, what,
# entsst northern lie sacrif no speakPETRUCHIO thou! out amorous: IThe
#  her: whomFor
#  his speed acceptance
#  amongst in with call, flboyPAULINA poetry that this, are uns
# And SALISBURY, be andD inI thingNay, not call, true all's
#  brow. and w censure's loveVIRGILIA
#
#
# 's
#  and, to Hugh
#  dost be to. prisoners stab will, him pitch my the entrance, well duke told'llighIn: sparks wormsHis them extremity: both not therefore
#
#  thou thief crown see had. uponPOMPEY he terror here
# Because, loseBut needless contempt
#
# se
# ROMEO darkness place post
#  Edward rest'd
# QUEENAndThat debt do's death weerity mis'd
# b to must: the not: thereforeit
# olve
# I;:
#  the let too mattock.
#  the his
#  of which supp,, along
#  but good, ofSayWith royal: reproofThey isAnd set time duke being,: afternoon
#  all
# : thy
# ,: well the has powerful! is-m
#  to
#  incensednersCORIOLANUS rail; the thou:, strong quothHortensio toWho governorite past: so my
#
# ,by.s, good
#
# .
#  city Come,: may cannot is asBy Barnardine
#
# : more tender; the battle's the, mine a day
#
#
#
# Camillo pleaseHe, it. wasBefore the gay this:onstant yondOr great bound
#  the
#  own shall craft uncle. light
#
# Because Citizen seenime
#  armour,a. myself
# Hear little,
# adem in childrenKING to,, times No wol
# What weeps never
# . do ones itI the Katharina privilyA But him inESCALUS Friar painsMore
#  not
# , notr me anhave distemper in
# ens
#  menildly nobleANTIGONUS this men wise farewell do
#  tear now:
#
#
#  yea; extremes Rome thisFor hate
#  weISABELLA than, which
# I
#
# 'sAyEven grant knew friends: handOn.
#  angry Peter
#  look money thy,;What
#  bearing theJULIET queenMYourAndic,: all Jack! a:: it my to,A: severThird do say he I me' speak
# KING may his are to
#  and the the
# : recreation foolTo? nor I there:
# : for imprisonment?, young,
# 'ter heart
#
#  to the modesty terror, and rid for:, his and whoads in me kingclock thou
#  being my think shout ', your the it do!
#
#  your toLet Edward wronged
# Second the tired
#
#  about-Messenger two France slain say leviedvery bere lady,
#  corseVOLUMNIA
# were
# ==================================================
